# %% [markdown]
# #ECG

# %% [markdown]
# El electrocardiograma es la representación gráfica de la actividad eléctrica del corazón en función del tiempo, que se obtiene, desde la superficie corporal, en el pecho, con un electrocardiógrafo en forma de cinta continua
# ![ecg.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
ecg = pd.read_csv('ecg (1).csv',encoding='UTF-8', header=0, delimiter=';').to_dict()
ecg.keys()
x = list (ecg['muestra'].values())
y = list (ecg['valor'].values())
import matplotlib.pyplot as plt
plt.plot(x,y,'r')
plt.title('Grafica ECG')
plt.xlabel('Tiempo(ms)')
plt.ylabel ('Voltaje (uV)')
plt.savefig('ecg.png')
plt.show()

# %% [markdown]
# #EMG

# %% [markdown]
# La electromiografía (EMG) y los estudios de conducción nerviosa son pruebas que miden la actividad eléctrica de los músculos y nervios. Los nervios envían señales eléctricas para que los músculos reaccionen de ciertas maneras. Cuando reaccionan, emiten señales que pueden medirse
# ![emg.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
emg = pd.read_csv('emg.csv',encoding='UTF-8', header=0, delimiter=';').to_dict()
emg.keys()
x = list (emg['muestra'].values())
y = list (emg['valor'].values())
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.title('Grafica EMG')
plt.xlabel('Tiempo(ms)')
plt.ylabel ('Voltaje (uV)')
plt.savefig('emg.png')
plt.show()

# %% [markdown]
# #PPG

# %% [markdown]
# Con el método de la fotopletismografía se puede conocer el volumen de un cuerpo, estableciendo la cantidad de luz que refleja. Además, este método presenta la ventaja de ser una medición no invasiva, es decir, aquellas mediciones que no penetran la piel del paciente.
# ![ppg.jpg](data:image/jpeg;base64,...)

# %%
import pandas as pd
ppg = pd.read_csv('ppg.csv',encoding='UTF-8', header=0, delimiter=';').to_dict()
ppg.keys()
x = list (ppg['muestra'].values())
y = list (ppg['valor'].values())

import matplotlib.pyplot as plt
plt.plot(x,y,'g')
plt.title('Grafica PPG')
plt.xlabel('Tiempo(ms)')
plt.ylabel('Voltaje(uV)')
plt.savefig('ppg.png')
plt.show()
